# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %% [markdown]
# ### Dataset Overview: Penguins
# Penguin data set shows body characteristics of penguins in relation to their sex and species.

# %%
df = sns.load_dataset('penguins')
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# ### Data Description
# A quick overview of the analyzed penguin characteristics: body mass, bill size and flipper length. Here we can see the average of each characteristic and percentiles from min to max.

# %%
df.describe().T
# Out:
#                    count         mean         std     min       25%      50%  \
# bill_length_mm     342.0    43.921930    5.459584    32.1    39.225    44.45
# bill_depth_mm      342.0    17.151170    1.974793    13.1    15.600    17.30
# flipper_length_mm  342.0   200.915205   14.061714   172.0   190.000   197.00
# body_mass_g        342.0  4201.754386  801.954536  2700.0  3550.000  4050.00
#
#                       75%     max
# bill_length_mm       48.5    59.6
# bill_depth_mm        18.7    21.5
# flipper_length_mm   213.0   231.0
# body_mass_g        4750.0  6300.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %% [markdown]
# ### Values
# Penguin data values showing count in categories of sex, species, and island.

# %%
df.sex.value_counts()
# Out:
# Male      168
# Female    165
# Name: sex, dtype: int64

# %%
df.species.value_counts()
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %%
df.island.value_counts()
# Out:
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: island, dtype: int64

# %% [markdown]
# ### Species data between male and female
# The given data set includes a majority from Adelie species, followed by Gentoo, with least count from Chinstrap. Male to female ratio is relatively similar.

# %%
sns.countplot(data=df, x='sex', hue='species')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0);

# %% [markdown]
# ### Island Data
# From the data below we can see that Adelie penguins occupy all three identified islands. In addition; Gentoos occupy Biscoe and Chinstraps occupy Dream.

# %%
sns.countplot(data=df, x='island', hue='species')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0);

# %% [markdown]
# ### Body Characteristics by Species
# The below data compares body mass, bill, and flipper sizes between the three species of penguins

# %% [markdown]
# ### Body Mass

# %%
sns.barplot(data=df, x='body_mass_g', y='species', palette='twilight');

# %%
# sns.boxplot(data=df, x='species', y='bill_length_mm', palette='BuGnb');

# %%
# sns.stripplot(data=df, x='species', y='bill_length_mm');

# %% [markdown]
# ### Bill Length

# %%
sns.displot(data=df, x='bill_length_mm', hue='species', kind='kde', palette='dark');

# %%
sns.boxplot(data=df, x='species', y='bill_length_mm', palette='BuGn');

# %% [markdown]
# ### Bill Depth

# %%
sns.displot(data=df, x='bill_depth_mm', hue='species', kind='kde', palette='dark');

# %%
sns.boxplot(data=df, x='species', y='bill_depth_mm', palette='BuGn');

# %% [markdown]
# ### Flipper Length

# %%
sns.displot(data=df, x='flipper_length_mm', hue='species', kind='kde', palette='dark');

# %%
sns.boxplot(data=df, x='species', y='flipper_length_mm', palette='BuGn');
